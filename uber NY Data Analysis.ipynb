# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as date
import warnings
warnings.filterwarnings('ignore')
from subprocess import check_output
df=pd.read_csv("/home/root1234/Downloads/My_Uber_Drives_2016.csv")
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.head(5)
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# 5           False      False      False   False  False   False     False
# 6           False      False      False   False  False   False     False
# 7           False      False      False   False  False   False     False
# 8           False      False      False   False  False   False     False
# 9           False      False      False   False  False   False     False
# 10          False      False      False   False  False   False     False
# 11          False      False      False   False  False   False     False
# ...

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uberdatacopy=df.copy()

# %%
uberdatacopy
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
start_list =[info.split(' ') for info in uberdatacopy['START_DATE*'].tolist()]

# %%
start_list
# Out:
# [['1/1/2016', '21:11'],
#  ['1/2/2016', '1:25'],
#  ['1/2/2016', '20:25'],
#  ['1/5/2016', '17:31'],
#  ['1/6/2016', '14:42'],
#  ['1/6/2016', '17:15'],
#  ['1/6/2016', '17:30'],
#  ['1/7/2016', '13:27'],
#  ['1/10/2016', '8:05'],
#  ['1/10/2016', '12:17'],
#  ['1/10/2016', '15:08'],
#  ['1/10/2016', '18:18'],
#  ['1/10/2016', '19:12'],
#  ['1/11/2016', '8:55'],
#  ['1/11/2016', '11:56'],
#  ['1/11/2016', '13:32'],
#  ['1/11/2016', '14:30'],
#  ['1/12/2016', '12:33'],
#  ['1/12/2016', '12:53'],
#  ['1/12/2016', '14:42'],
#  ['1/12/2016', '15:13'],
#  ['1/12/2016', '15:42'],
#  ['1/12/2016', '16:02'],
#  ['1/13/2016', '13:54'],
#  ['1/13/2016', '15:00'],
#  ['1/14/2016', '16:29'],
#  ['1/14/2016', '21:39'],
#  ['1/15/2016', '0:41'],
#  ['1/15/2016', '11:43'],
#  ['1/15/2016', '13:26'],
#  ['1/18/2016', '14:55'],
#  ['1/18/2016', '16:13'],
#  ['1/19/2016', '9:09'],
#  ['1/19/2016', '10:55'],
#  ['1/20/2016', '10:36'],
#  ['1/20/2016', '11:48'],
#  ['1/20/2016', '13:25'],
# ...

# %%
uberdatacopy.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
stop_list =[i.split(' ') for i in uberdatacopy['END_DATE*'].tolist()]

# %%
stop_list
# Out:
# [['1/1/2016', '21:17'],
#  ['1/2/2016', '1:37'],
#  ['1/2/2016', '20:38'],
#  ['1/5/2016', '17:45'],
#  ['1/6/2016', '15:49'],
#  ['1/6/2016', '17:19'],
#  ['1/6/2016', '17:35'],
#  ['1/7/2016', '13:33'],
#  ['1/10/2016', '8:25'],
#  ['1/10/2016', '12:44'],
#  ['1/10/2016', '15:51'],
#  ['1/10/2016', '18:53'],
#  ['1/10/2016', '19:32'],
#  ['1/11/2016', '9:21'],
#  ['1/11/2016', '12:03'],
#  ['1/11/2016', '13:46'],
#  ['1/11/2016', '14:43'],
#  ['1/12/2016', '12:49'],
#  ['1/12/2016', '13:09'],
#  ['1/12/2016', '14:56'],
#  ['1/12/2016', '15:28'],
#  ['1/12/2016', '15:54'],
#  ['1/12/2016', '17:00'],
#  ['1/13/2016', '14:07'],
#  ['1/13/2016', '15:28'],
#  ['1/14/2016', '17:05'],
#  ['1/14/2016', '21:45'],
#  ['1/15/2016', '1:01'],
#  ['1/15/2016', '12:03'],
#  ['1/15/2016', '13:44'],
#  ['1/18/2016', '15:06'],
#  ['1/18/2016', '16:24'],
#  ['1/19/2016', '9:23'],
#  ['1/19/2016', '11:09'],
#  ['1/20/2016', '11:11'],
#  ['1/20/2016', '12:19'],
#  ['1/20/2016', '14:19'],
# ...

# %%
uberdatacopy
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
uberdatacopy=uberdatacopy.drop(uberdatacopy.index[1154])
uberdatacopy
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
uberdatacopy.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
start=pd.DataFrame(start_list,columns=['Start_Date','Start_Time'])

stop=pd.DataFrame(stop_list,columns=['End_Date','End_Time'])
# Out:
#         End_Date End_Time
# 0       1/1/2016    21:17
# 1       1/2/2016     1:37
# 2       1/2/2016    20:38
# 3       1/5/2016    17:45
# 4       1/6/2016    15:49
# 5       1/6/2016    17:19
# 6       1/6/2016    17:35
# 7       1/7/2016    13:33
# 8      1/10/2016     8:25
# 9      1/10/2016    12:44
# 10     1/10/2016    15:51
# 11     1/10/2016    18:53
# 12     1/10/2016    19:32
# 13     1/11/2016     9:21
# 14     1/11/2016    12:03
# 15     1/11/2016    13:46
# 16     1/11/2016    14:43
# 17     1/12/2016    12:49
# 18     1/12/2016    13:09
# 19     1/12/2016    14:56
# 20     1/12/2016    15:28
# 21     1/12/2016    15:54
# 22     1/12/2016    17:00
# 23     1/13/2016    14:07
# 24     1/13/2016    15:28
# 25     1/14/2016    17:05
# 26     1/14/2016    21:45
# 27     1/15/2016     1:01
# 28     1/15/2016    12:03
# 29     1/15/2016    13:44
# ...          ...      ...
# 1124  12/27/2016    19:50
# 1125  12/28/2016     9:06
# 1126  12/28/2016    12:12
# ...

# %%
start
# Out:
#       Start_Date Start_Time
# 0       1/1/2016      21:11
# 1       1/2/2016       1:25
# 2       1/2/2016      20:25
# 3       1/5/2016      17:31
# 4       1/6/2016      14:42
# 5       1/6/2016      17:15
# 6       1/6/2016      17:30
# 7       1/7/2016      13:27
# 8      1/10/2016       8:05
# 9      1/10/2016      12:17
# 10     1/10/2016      15:08
# 11     1/10/2016      18:18
# 12     1/10/2016      19:12
# 13     1/11/2016       8:55
# 14     1/11/2016      11:56
# 15     1/11/2016      13:32
# 16     1/11/2016      14:30
# 17     1/12/2016      12:33
# 18     1/12/2016      12:53
# 19     1/12/2016      14:42
# 20     1/12/2016      15:13
# 21     1/12/2016      15:42
# 22     1/12/2016      16:02
# 23     1/13/2016      13:54
# 24     1/13/2016      15:00
# 25     1/14/2016      16:29
# 26     1/14/2016      21:39
# 27     1/15/2016       0:41
# 28     1/15/2016      11:43
# 29     1/15/2016      13:26
# ...          ...        ...
# 1126  12/28/2016      11:42
# ...

# %%
    stop
# Out:
#         End_Date End_Time
# 0       1/1/2016    21:17
# 1       1/2/2016     1:37
# 2       1/2/2016    20:38
# 3       1/5/2016    17:45
# 4       1/6/2016    15:49
# 5       1/6/2016    17:19
# 6       1/6/2016    17:35
# 7       1/7/2016    13:33
# 8      1/10/2016     8:25
# 9      1/10/2016    12:44
# 10     1/10/2016    15:51
# 11     1/10/2016    18:53
# 12     1/10/2016    19:32
# 13     1/11/2016     9:21
# 14     1/11/2016    12:03
# 15     1/11/2016    13:46
# 16     1/11/2016    14:43
# 17     1/12/2016    12:49
# 18     1/12/2016    13:09
# 19     1/12/2016    14:56
# 20     1/12/2016    15:28
# 21     1/12/2016    15:54
# 22     1/12/2016    17:00
# 23     1/13/2016    14:07
# 24     1/13/2016    15:28
# 25     1/14/2016    17:05
# 26     1/14/2016    21:45
# 27     1/15/2016     1:01
# 28     1/15/2016    12:03
# 29     1/15/2016    13:44
# ...          ...      ...
# 1124  12/27/2016    19:50
# 1125  12/28/2016     9:06
# 1126  12/28/2016    12:12
# ...

# %%
sub_split=uberdatacopy[['CATEGORY*','START*','STOP*','MILES*','PURPOSE*']]

# %%
merge_start_stop=pd.concat([start,stop],axis=1)

# %%
uberdatacopy=pd.concat([merge_start_stop,sub_split],axis=1)

# %%
uberdatacopy
# Out:
#       Start_Date Start_Time    End_Date End_Time CATEGORY*             START*  \
# 0       1/1/2016      21:11    1/1/2016    21:17  Business        Fort Pierce
# 1       1/2/2016       1:25    1/2/2016     1:37  Business        Fort Pierce
# 2       1/2/2016      20:25    1/2/2016    20:38  Business        Fort Pierce
# 3       1/5/2016      17:31    1/5/2016    17:45  Business        Fort Pierce
# 4       1/6/2016      14:42    1/6/2016    15:49  Business        Fort Pierce
# 5       1/6/2016      17:15    1/6/2016    17:19  Business    West Palm Beach
# 6       1/6/2016      17:30    1/6/2016    17:35  Business    West Palm Beach
# 7       1/7/2016      13:27    1/7/2016    13:33  Business               Cary
# 8      1/10/2016       8:05   1/10/2016     8:25  Business               Cary
# 9      1/10/2016      12:17   1/10/2016    12:44  Business            Jamaica
# 10     1/10/2016      15:08   1/10/2016    15:51  Business           New York
# ...
